# %%
a=int(input("enter 1st number"))
b=int(input("enter 2nd number"))
c=int(input("select an operation, 1=+, 2=-, 3=*, 4=/,5=%"))
if c==1:
    print(a+b)
elif c==2:
    print(a-b)
elif c==3:
    print(a*b)
elif c==4:
    print(a/b)
else:
    print(a%b)
# Out:
# enter 1st number 1048
# enter 2nd number 8041
# select an operation, 1=+, 2=-, 3=*, 4=/,5=% 4
# 0.1303320482527049
